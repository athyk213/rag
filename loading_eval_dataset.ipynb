# %%
import pickle
    
eval_dataset_path = "/home/mc76728/repo/Coargus/vrag/generator_eval_dataset_gemini.pkl"
# Read the results back from the pickle file for testing
with open(eval_dataset_path, "rb") as f:
    loaded_results = pickle.load(f)

print(f"Total number of questions: {len(loaded_results)}")
sample = loaded_results[0:5]
for result in sample:
    print(result)
    print("-" * 35 + "\n")
# Out:
# Total number of questions: 77
# {'question': 'According to the lecture, what mathematical prerequisites are essential for this machine learning course, and which of these will be reviewed in class?', 'answer': "The lecture states that a basic understanding of linear algebra is a prerequisite for the course. While other topics like probability, multivariate statistics, and optimization will be used, the professor mentions that they will review the necessary linear algebra in one lecture to refresh students' memories and highlight its relevance to the course."}
# -----------------------------------
#
# {'question': 'According to the lecture, what background is a prerequisite for the course, and what topics involving mathematics will be reviewed?', 'answer': 'A decent background in linear algebra is a prerequisite. The lecture also mentions that multivariable calculus and linear algebra will be reviewed, specifically in the context of regression.'}
# -----------------------------------
#
# {'question': 'According to the lecture, what cornerstone method in linear algebra will be discussed in relation to regression?', 'answer': 'The lecture mentions that Singular Value Decomposition (SVD) will be discussed as a cornerstone method in linear algebra and its relation to regression will be explored.'}
# -----------------------------------
#
# {'question': 'Several students mentioned a desire to strengthen their understanding of the "mathematical foundation" or "theory" behind machine learning algorithms. Can you list at least three specific mathematical areas that are fundamental to understanding machine learning algorithms at a deeper, theoretical level?', 'answer': 'Based on the course description and student comments, key mathematical areas fundamental to machine learning include Linear Algebra (for understanding data representation and transformations), Probability (for modeling uncertainty and making predictions), and Calculus (for optimization and gradient-based learning).'}
# -----------------------------------
#
# {'question': 'Based on the introductions, which student explicitly mentioned using computer vision in their research?', 'answer': 'Mir Mohammad Shamszadeh, a Ph.D. student in civil engineering, mentioned that his project involves applications of AI, particularly computer vision, for structural monitoring of bridges.'}
# -----------------------------------

# %%
loaded_results[69]
# Out:
# {'question': 'Describe the four components of a neuron in a deep neural network, as discussed in the lecture.',
#  'answer': "A neuron in a deep neural network consists of four key components: multiple scalar inputs, weights assigned to each input that determine the importance of that input in activating the neuron, a summation that adds up all the weighted inputs, and a nonlinearity or activation function that filters the weighted sum to determine the neuron's output."}
